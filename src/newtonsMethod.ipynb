# %%
from sympy import *
x = Symbol('x')
y = Symbol('y')
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
T = Symbol('T')
xn = Symbol('xn')
x0 = 0.5
f = x0 + (-xn + (-a*(xn**3/3-xn)+a*(y+(-xn+c)*T/(1+b*T)))*T + x)/(a*T*(-T/(b*T + 1) + xn**2 + 1) - 1)
f
l = [2]
for i in range(10):
    l.append(l[-1] + f.subs([(xn, l[-1]), (a, 100), (b, 1.2), (c, 0.5), (T, 0.001), (x, 2), (y, 0)]))
    print(l[-1])
print(l)
# Out:
# 2.63360628453498
# 7.87589596639495
# 4.34530759536174
# 0.143156828391377
# -1.44035263708841
# -5.84351360360774
# 0.188659365259111
# -1.35253514327919
# -5.45390751157049
# 0.983527836343296
# 0.135372747759143
# -1.45545060517973
# -5.91410152305611
# 0.0596910280781930
# -1.60349747422151
# -6.67255319650481
# -1.13095660812695
# -4.60177776743155
# 3.61085351369706
# -2.87255721217839
# -74.1051951225968
# -48.7375995873959
# -31.7361005729526
# -20.2557931172191
# -12.3482440558368
# -6.55988739072948
# -0.972152649989262
# -4.07907844072052
# 6.80862394689806
# 3.38710012591623
# -5.59703882906058
# 0.673192644127547
# -0.445865116043601
# -2.67737174678259
# -29.7309852487553
# -18.8899804272107
# -11.3840509164096
# -5.79061135654240
# 0.287977532395440
# -1.16316858120853
# -4.71580976555332
# 3.14229466022567
# -17.6925111845355
# -10.5308104485218
# -5.08394950366186
# 1.91996413981673
# 2.35227674426768
# 4.44143870444615
# 0.355923875056705
# -1.03512862412671
# ...
